# %%
#pip install basketball_reference_web_scraper

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
import pandas as pd
from basketball_reference_web_scraper import client
response = client.players_season_totals(season_end_year=2020)
df = pd.DataFrame(response)
cols = ['name', 'team', 'positions', 'age', 'assists', 'attempted_field_goals', 'attempted_free_throws',
       'attempted_three_point_field_goals', 'blocks', 'defensive_rebounds',
       'games_played', 'games_started', 'made_field_goals', 'made_free_throws',
       'made_three_point_field_goals', 'minutes_played',
       'offensive_rebounds', 'personal_fouls', 'points', 'slug',
       'steals', 'turnovers']
df[cols]
# Out:
#                          name                        team  \
# 0                Steven Adams  Team.OKLAHOMA_CITY_THUNDER
# 1                 Bam Adebayo             Team.MIAMI_HEAT
# 2           LaMarcus Aldridge      Team.SAN_ANTONIO_SPURS
# 3    Nickeil Alexander-Walker   Team.NEW_ORLEANS_PELICANS
# 4               Grayson Allen      Team.MEMPHIS_GRIZZLIES
# ..                        ...                         ...
# 562            Thaddeus Young          Team.CHICAGO_BULLS
# 563                Trae Young          Team.ATLANTA_HAWKS
# 564               Cody Zeller      Team.CHARLOTTE_HORNETS
# 565                Ante Žižić    Team.CLEVELAND_CAVALIERS
# 566               Ivica Zubac   Team.LOS_ANGELES_CLIPPERS
#
#                      positions  age  assists  attempted_field_goals  \
# 0            [Position.CENTER]   26      136                    428
# 1     [Position.POWER_FORWARD]   22      309                    672
# 2            [Position.CENTER]   34      127                    770
# 3    [Position.SHOOTING_GUARD]   21       74                    227
# 4    [Position.SHOOTING_GUARD]   24       43                    176
# ..                         ...  ...      ...                    ...
# 562   [Position.POWER_FORWARD]   31      107                    560
# 563     [Position.POINT_GUARD]   21      529                   1183
# 564          [Position.CENTER]   27       80                    455
# 565          [Position.CENTER]   23        6                     66
# 566          [Position.CENTER]   22       68                    324
#
#      attempted_free_throws  attempted_three_point_field_goals  blocks  \
# 0                      170                                  3      61
# 1                      326                                 13      79
# 2                      187                                153      83
# 3                       28                                117       7
# 4                       35                                 91       1
# ..                     ...                                ...     ...
# 562                     64                                205      20
# 563                    531                                533       8
# 564                    159                                 72      24
# 565                     18                                  0       5
# 566                    129                                  2      57
#
#      defensive_rebounds  ...  made_field_goals  made_free_throws  \
# 0                   329  ...               252               102
# 1                   489  ...               380               225
# 2                   287  ...               381               155
# 3                    72  ...                77                17
# 4                    61  ...                79                30
# ..                  ...  ...               ...               ...
# 562                 205  ...               251                38
# 563                 214  ...               519               459
# 564                 234  ...               236               106
# 565                  47  ...                39                14
# 566                 274  ...               194                97
#
#      made_three_point_field_goals  minutes_played  offensive_rebounds  \
# 0                               1            1482                 190
# 1                               1            2100                 154
# 2                              60            1717                 103
# 3                              40             501                   8
# 4                              33             498                   5
# ..                            ...             ...                 ...
# 562                            75            1490                  88
# 563                           192            2010                  30
# 564                            17            1243                 149
# 565                             0             202                  15
# 566                             0            1102                 156
#
#      personal_fouls  points       slug  steals turnovers
# 0               109     607  adamsst01      44        80
# 1               150     986  adebaba01      75       171
# 2               127     977  aldrila01      33        73
# 3                46     211  alexani01      11        40
# 4                36     221  allengr01       6        23
# ..              ...     ...        ...     ...       ...
# 562             124     615  youngth01      82        96
# 563              96    1689  youngtr01      63       272
# 564             133     595  zelleco01      36        68
# 565              25      92  zizican01       7        10
# 566             141     485  zubaciv01      13        51
#
# [567 rows x 22 columns]

# %%
new_player_data = df[['name', 'team', 'positions', 'attempted_field_goals','attempted_free_throws',
       'attempted_three_point_field_goals', 'blocks', 'defensive_rebounds',
       'games_played', 'games_started', 'made_field_goals', 'made_free_throws',
       'made_three_point_field_goals', 'minutes_played',
       'offensive_rebounds', 'points',
       'steals']].copy()
new_player_data.head()
# Out:
#                        name                        team  \
# 0              Steven Adams  Team.OKLAHOMA_CITY_THUNDER
# 1               Bam Adebayo             Team.MIAMI_HEAT
# 2         LaMarcus Aldridge      Team.SAN_ANTONIO_SPURS
# 3  Nickeil Alexander-Walker   Team.NEW_ORLEANS_PELICANS
# 4             Grayson Allen      Team.MEMPHIS_GRIZZLIES
#
#                    positions  attempted_field_goals  attempted_free_throws  \
# 0          [Position.CENTER]                    428                    170
# 1   [Position.POWER_FORWARD]                    672                    326
# 2          [Position.CENTER]                    770                    187
# 3  [Position.SHOOTING_GUARD]                    227                     28
# 4  [Position.SHOOTING_GUARD]                    176                     35
#
#    attempted_three_point_field_goals  blocks  defensive_rebounds  \
# 0                                  3      61                 329
# 1                                 13      79                 489
# 2                                153      83                 287
# 3                                117       7                  72
# 4                                 91       1                  61
#
#    games_played  games_started  made_field_goals  made_free_throws  \
# 0            55             55               252               102
# 1            61             61               380               225
# 2            52             52               381               155
# 3            41              0                77                17
# 4            30              0                79                30
#
#    made_three_point_field_goals  minutes_played  offensive_rebounds  points  \
# 0                             1            1482                 190     607
# 1                             1            2100                 154     986
# 2                            60            1717                 103     977
# 3                            40             501                   8     211
# 4                            33             498                   5     221
#
#    steals
# 0      44
# 1      75
# 2      33
# 3      11
# 4       6

# %%
new_player_data = new_player_data.rename(columns={'name':"Player"})
new_player_data.head()
# Out:
#                      Player                        team  \
# 0              Steven Adams  Team.OKLAHOMA_CITY_THUNDER
# 1               Bam Adebayo             Team.MIAMI_HEAT
# 2         LaMarcus Aldridge      Team.SAN_ANTONIO_SPURS
# 3  Nickeil Alexander-Walker   Team.NEW_ORLEANS_PELICANS
# 4             Grayson Allen      Team.MEMPHIS_GRIZZLIES
#
#                    positions  attempted_field_goals  attempted_free_throws  \
# 0          [Position.CENTER]                    428                    170
# 1   [Position.POWER_FORWARD]                    672                    326
# 2          [Position.CENTER]                    770                    187
# 3  [Position.SHOOTING_GUARD]                    227                     28
# 4  [Position.SHOOTING_GUARD]                    176                     35
#
#    attempted_three_point_field_goals  blocks  defensive_rebounds  \
# 0                                  3      61                 329
# 1                                 13      79                 489
# 2                                153      83                 287
# 3                                117       7                  72
# 4                                 91       1                  61
#
#    games_played  games_started  made_field_goals  made_free_throws  \
# 0            55             55               252               102
# 1            61             61               380               225
# 2            52             52               381               155
# 3            41              0                77                17
# 4            30              0                79                30
#
#    made_three_point_field_goals  minutes_played  offensive_rebounds  points  \
# 0                             1            1482                 190     607
# 1                             1            2100                 154     986
# 2                            60            1717                 103     977
# 3                            40             501                   8     211
# 4                            33             498                   5     221
#
#    steals
# 0      44
# 1      75
# 2      33
# 3      11
# 4       6

# %%
new_player_data['fg_pcg'] = round(new_player_data['made_field_goals'] / new_player_data['attempted_field_goals'],2)
new_player_data.head()
# Out:
#                      Player                        team  \
# 0              Steven Adams  Team.OKLAHOMA_CITY_THUNDER
# 1               Bam Adebayo             Team.MIAMI_HEAT
# 2         LaMarcus Aldridge      Team.SAN_ANTONIO_SPURS
# 3  Nickeil Alexander-Walker   Team.NEW_ORLEANS_PELICANS
# 4             Grayson Allen      Team.MEMPHIS_GRIZZLIES
#
#                    positions  attempted_field_goals  attempted_free_throws  \
# 0          [Position.CENTER]                    428                    170
# 1   [Position.POWER_FORWARD]                    672                    326
# 2          [Position.CENTER]                    770                    187
# 3  [Position.SHOOTING_GUARD]                    227                     28
# 4  [Position.SHOOTING_GUARD]                    176                     35
#
#    attempted_three_point_field_goals  blocks  defensive_rebounds  \
# 0                                  3      61                 329
# 1                                 13      79                 489
# 2                                153      83                 287
# 3                                117       7                  72
# 4                                 91       1                  61
#
#    games_played  games_started  made_field_goals  made_free_throws  \
# 0            55             55               252               102
# 1            61             61               380               225
# 2            52             52               381               155
# 3            41              0                77                17
# 4            30              0                79                30
#
#    made_three_point_field_goals  minutes_played  offensive_rebounds  points  \
# 0                             1            1482                 190     607
# 1                             1            2100                 154     986
# 2                            60            1717                 103     977
# 3                            40             501                   8     211
# 4                            33             498                   5     221
#
#    steals  fg_pcg
# 0      44    0.59
# 1      75    0.57
# 2      33    0.49
# 3      11    0.34
# 4       6    0.45

# %%
new_player_data['3pt_pcg'] = round(new_player_data['made_three_point_field_goals'] / new_player_data['attempted_three_point_field_goals'],2)
new_player_data.head()
# Out:
#                      Player                        team  \
# 0              Steven Adams  Team.OKLAHOMA_CITY_THUNDER
# 1               Bam Adebayo             Team.MIAMI_HEAT
# 2         LaMarcus Aldridge      Team.SAN_ANTONIO_SPURS
# 3  Nickeil Alexander-Walker   Team.NEW_ORLEANS_PELICANS
# 4             Grayson Allen      Team.MEMPHIS_GRIZZLIES
#
#                    positions  attempted_field_goals  attempted_free_throws  \
# 0          [Position.CENTER]                    428                    170
# 1   [Position.POWER_FORWARD]                    672                    326
# 2          [Position.CENTER]                    770                    187
# 3  [Position.SHOOTING_GUARD]                    227                     28
# 4  [Position.SHOOTING_GUARD]                    176                     35
#
#    attempted_three_point_field_goals  blocks  defensive_rebounds  \
# 0                                  3      61                 329
# 1                                 13      79                 489
# 2                                153      83                 287
# 3                                117       7                  72
# 4                                 91       1                  61
#
#    games_played  games_started  made_field_goals  made_free_throws  \
# 0            55             55               252               102
# 1            61             61               380               225
# 2            52             52               381               155
# 3            41              0                77                17
# 4            30              0                79                30
#
#    made_three_point_field_goals  minutes_played  offensive_rebounds  points  \
# 0                             1            1482                 190     607
# 1                             1            2100                 154     986
# 2                            60            1717                 103     977
# 3                            40             501                   8     211
# 4                            33             498                   5     221
#
#    steals  fg_pcg  3pt_pcg
# 0      44    0.59     0.33
# 1      75    0.57     0.08
# 2      33    0.49     0.39
# 3      11    0.34     0.34
# 4       6    0.45     0.36

# %%
new_player_data['ft_pcg'] = round(new_player_data['made_free_throws'] / new_player_data['attempted_free_throws'],2)
new_player_data.head()
# Out:
#                      Player                        team  \
# 0              Steven Adams  Team.OKLAHOMA_CITY_THUNDER
# 1               Bam Adebayo             Team.MIAMI_HEAT
# 2         LaMarcus Aldridge      Team.SAN_ANTONIO_SPURS
# 3  Nickeil Alexander-Walker   Team.NEW_ORLEANS_PELICANS
# 4             Grayson Allen      Team.MEMPHIS_GRIZZLIES
#
#                    positions  attempted_field_goals  attempted_free_throws  \
# 0          [Position.CENTER]                    428                    170
# 1   [Position.POWER_FORWARD]                    672                    326
# 2          [Position.CENTER]                    770                    187
# 3  [Position.SHOOTING_GUARD]                    227                     28
# 4  [Position.SHOOTING_GUARD]                    176                     35
#
#    attempted_three_point_field_goals  blocks  defensive_rebounds  \
# 0                                  3      61                 329
# 1                                 13      79                 489
# 2                                153      83                 287
# 3                                117       7                  72
# 4                                 91       1                  61
#
#    games_played  games_started  made_field_goals  made_free_throws  \
# 0            55             55               252               102
# 1            61             61               380               225
# 2            52             52               381               155
# 3            41              0                77                17
# 4            30              0                79                30
#
#    made_three_point_field_goals  minutes_played  offensive_rebounds  points  \
# 0                             1            1482                 190     607
# 1                             1            2100                 154     986
# 2                            60            1717                 103     977
# 3                            40             501                   8     211
# 4                            33             498                   5     221
#
#    steals  fg_pcg  3pt_pcg  ft_pcg
# 0      44    0.59     0.33    0.60
# 1      75    0.57     0.08    0.69
# 2      33    0.49     0.39    0.83
# 3      11    0.34     0.34    0.61
# 4       6    0.45     0.36    0.86

# %%
csv_file = "war_data.csv"
war_data_df = pd.read_csv(csv_file)
war_data_df.head()
# Out:
#                 player_name  player_id  season  poss    mp  \
# 0              Steven Adams  adamsst01    2020  3055  1455
# 1               Bam Adebayo  adebaba01    2020  4236  2063
# 2         LaMarcus Aldridge  aldrila01    2020  3570  1717
# 3  Nickeil Alexander-Walker  alexani01    2020  1098   501
# 4             Grayson Allen  allengr01    2020  1100   498
#
#    raptor_box_offense  raptor_box_defense  raptor_box_total  \
# 0            1.069307            1.017527          2.086834
# 1           -0.877707            2.281325          1.403618
# 2           -0.579002            0.477111         -0.101891
# 3           -3.206619           -1.605278         -4.811897
# 4           -0.279106           -1.470201         -1.749307
#
#    raptor_onoff_offense  raptor_onoff_defense  ...  raptor_offense  \
# 0              1.072663              0.971245  ...        1.125738
# 1              2.988185              0.824550  ...       -0.165734
# 2             -0.925832             -2.628988  ...       -0.719501
# 3              0.634448             -3.492007  ...       -2.609379
# 4             -0.892021             -2.904853  ...       -0.402876
#
#    raptor_defense  raptor_total  war_total  war_reg_season  war_playoffs  \
# 0        1.078578      2.204317   3.659296        3.659296             0
# 1        2.099525      1.933791   4.898266        4.898266             0
# 2       -0.101252     -0.820753   1.666244        1.666244             0
# 3       -2.066637     -4.676016  -0.494786       -0.494786             0
# 4       -1.847584     -2.250460   0.127522        0.127522             0
#
#    predator_offense  predator_defense  predator_total  pace_impact
# 0          0.541974          1.404645        1.946619    -0.513132
# 1         -0.265390          1.207401        0.942011    -0.654490
# 2         -0.687945          0.457627       -0.230318    -1.436922
# 3         -1.143853         -2.200515       -3.344368     0.513285
# 4         -0.703484         -2.503757       -3.207241     0.481662
#
# [5 rows x 21 columns]

# %%
new_war_data = war_data_df[['player_name','raptor_offense', 'raptor_defense', 'raptor_total', 'war_total']]
new_war_data.head()
# Out:
#                 player_name  raptor_offense  raptor_defense  raptor_total  \
# 0              Steven Adams        1.125738        1.078578      2.204317
# 1               Bam Adebayo       -0.165734        2.099525      1.933791
# 2         LaMarcus Aldridge       -0.719501       -0.101252     -0.820753
# 3  Nickeil Alexander-Walker       -2.609379       -2.066637     -4.676016
# 4             Grayson Allen       -0.402876       -1.847584     -2.250460
#
#    war_total
# 0   3.659296
# 1   4.898266
# 2   1.666244
# 3  -0.494786
# 4   0.127522

# %%
new_war_data = new_war_data.rename(columns={'player_name':"Player"})
new_war_data.head()
# Out:
#                      Player  raptor_offense  raptor_defense  raptor_total  \
# 0              Steven Adams        1.125738        1.078578      2.204317
# 1               Bam Adebayo       -0.165734        2.099525      1.933791
# 2         LaMarcus Aldridge       -0.719501       -0.101252     -0.820753
# 3  Nickeil Alexander-Walker       -2.609379       -2.066637     -4.676016
# 4             Grayson Allen       -0.402876       -1.847584     -2.250460
#
#    war_total
# 0   3.659296
# 1   4.898266
# 2   1.666244
# 3  -0.494786
# 4   0.127522

# %%
url = "https://nba2kw.com/list/nba-2k20-all-player-ratings/"

# %%
nba2k_tables = pd.read_html(url)

# %%
nba2k_df = nba2k_tables[0]
nba2k_df
# Out:
#      Rank                 Player           Team Pos. Height  \
# 0       1           James Harden        Rockets   SG   6'5"
# 1       2           LeBron James         Lakers   SF   6'9"
# 2       3  Giannis Antetokounmpo          Bucks   PF  6'11"
# 3       4          Kawhi Leonard       Clippers   SF   6'7"
# 4       5          Anthony Davis         Lakers   PF  6'10"
# ..    ...                    ...            ...  ...    ...
# 504   505             Devon Hall              -   SG   6'2"
# 505   506            Moses Brown  Trail Blazers    C   7'2"
# 506   507          Marial Shayok          76ers   SG   6'5"
# 507   508           Kobi Simmons        Hornets   PG   6'5"
# 508   509        Naz Mitrou-Long         Pacers   PG   6'3"
#
#                         Build  OVR
# 0            Offensive Threat   97
# 1    2-Way Slashing Playmaker   97
# 2    2-Way Slashing Playmaker   97
# 3               2-Way Slasher   96
# 4              Interior Force   96
# ..                        ...  ...
# 504              Shot Creator   67
# 505            Paint Defender   67
# 506           3 PT Specialist   67
# 507     Floor-Spacing Slasher   66
# 508   Playmaking Shot Creator   66
#
# [509 rows x 7 columns]

# %%
new_nba2k_df = nba2k_df[['Player','Team','Pos.','Build','OVR']].copy()
new_nba2k_df
# Out:
#                     Player           Team Pos.                     Build  OVR
# 0             James Harden        Rockets   SG          Offensive Threat   97
# 1             LeBron James         Lakers   SF  2-Way Slashing Playmaker   97
# 2    Giannis Antetokounmpo          Bucks   PF  2-Way Slashing Playmaker   97
# 3            Kawhi Leonard       Clippers   SF             2-Way Slasher   96
# 4            Anthony Davis         Lakers   PF            Interior Force   96
# ..                     ...            ...  ...                       ...  ...
# 504             Devon Hall              -   SG              Shot Creator   67
# 505            Moses Brown  Trail Blazers    C            Paint Defender   67
# 506          Marial Shayok          76ers   SG           3 PT Specialist   67
# 507           Kobi Simmons        Hornets   PG     Floor-Spacing Slasher   66
# 508        Naz Mitrou-Long         Pacers   PG   Playmaking Shot Creator   66
#
# [509 rows x 5 columns]

# %%
final_df = new_player_data.merge(new_war_data, how ='left', on='Player')
final_df
# Out:
#                        Player                        team  \
# 0                Steven Adams  Team.OKLAHOMA_CITY_THUNDER
# 1                 Bam Adebayo             Team.MIAMI_HEAT
# 2           LaMarcus Aldridge      Team.SAN_ANTONIO_SPURS
# 3    Nickeil Alexander-Walker   Team.NEW_ORLEANS_PELICANS
# 4               Grayson Allen      Team.MEMPHIS_GRIZZLIES
# ..                        ...                         ...
# 562            Thaddeus Young          Team.CHICAGO_BULLS
# 563                Trae Young          Team.ATLANTA_HAWKS
# 564               Cody Zeller      Team.CHARLOTTE_HORNETS
# 565                Ante Žižić    Team.CLEVELAND_CAVALIERS
# 566               Ivica Zubac   Team.LOS_ANGELES_CLIPPERS
#
#                      positions  attempted_field_goals  attempted_free_throws  \
# 0            [Position.CENTER]                    428                    170
# 1     [Position.POWER_FORWARD]                    672                    326
# 2            [Position.CENTER]                    770                    187
# 3    [Position.SHOOTING_GUARD]                    227                     28
# 4    [Position.SHOOTING_GUARD]                    176                     35
# ..                         ...                    ...                    ...
# 562   [Position.POWER_FORWARD]                    560                     64
# 563     [Position.POINT_GUARD]                   1183                    531
# 564          [Position.CENTER]                    455                    159
# 565          [Position.CENTER]                     66                     18
# 566          [Position.CENTER]                    324                    129
#
#      attempted_three_point_field_goals  blocks  defensive_rebounds  \
# 0                                    3      61                 329
# 1                                   13      79                 489
# 2                                  153      83                 287
# 3                                  117       7                  72
# 4                                   91       1                  61
# ..                                 ...     ...                 ...
# 562                                205      20                 205
# 563                                533       8                 214
# 564                                 72      24                 234
# 565                                  0       5                  47
# 566                                  2      57                 274
#
#      games_played  games_started  ...  offensive_rebounds  points  steals  \
# 0              55             55  ...                 190     607      44
# 1              61             61  ...                 154     986      75
# 2              52             52  ...                 103     977      33
# 3              41              0  ...                   8     211      11
# 4              30              0  ...                   5     221       6
# ..            ...            ...  ...                 ...     ...     ...
# 562            60             16  ...                  88     615      82
# 563            57             57  ...                  30    1689      63
# 564            54             35  ...                 149     595      36
# 565            20              0  ...                  15      92       7
# 566            61             59  ...                 156     485      13
#
#      fg_pcg  3pt_pcg  ft_pcg  raptor_offense  raptor_defense  raptor_total  \
# 0      0.59     0.33    0.60        1.125738        1.078578      2.204317
# 1      0.57     0.08    0.69       -0.165734        2.099525      1.933791
# 2      0.49     0.39    0.83       -0.719501       -0.101252     -0.820753
# 3      0.34     0.34    0.61       -2.609379       -2.066637     -4.676016
# 4      0.45     0.36    0.86       -0.402876       -1.847584     -2.250460
# ..      ...      ...     ...             ...             ...           ...
# 562    0.45     0.37    0.59       -2.956376        0.714684     -2.241691
# 563    0.44     0.36    0.86        7.500200       -3.191613      4.308588
# 564    0.52     0.24    0.67       -0.596286       -1.628820     -2.225105
# 565    0.59      NaN    0.78             NaN             NaN           NaN
# 566    0.60     0.00    0.75        0.535135        3.020559      3.555694
#
#      war_total
# 0     3.659296
# 1     4.898266
# 2     1.666244
# 3    -0.494786
# 4     0.127522
# ..         ...
# 562   0.379694
# 563   7.325524
# 564   0.327500
# 565        NaN
# 566   3.469482
#
# [567 rows x 24 columns]

# %%
final_df = final_df.merge(new_nba2k_df, how='left', on='Player')
final_df
# Out:
#                        Player                        team  \
# 0                Steven Adams  Team.OKLAHOMA_CITY_THUNDER
# 1                 Bam Adebayo             Team.MIAMI_HEAT
# 2           LaMarcus Aldridge      Team.SAN_ANTONIO_SPURS
# 3    Nickeil Alexander-Walker   Team.NEW_ORLEANS_PELICANS
# 4               Grayson Allen      Team.MEMPHIS_GRIZZLIES
# ..                        ...                         ...
# 562            Thaddeus Young          Team.CHICAGO_BULLS
# 563                Trae Young          Team.ATLANTA_HAWKS
# 564               Cody Zeller      Team.CHARLOTTE_HORNETS
# 565                Ante Žižić    Team.CLEVELAND_CAVALIERS
# 566               Ivica Zubac   Team.LOS_ANGELES_CLIPPERS
#
#                      positions  attempted_field_goals  attempted_free_throws  \
# 0            [Position.CENTER]                    428                    170
# 1     [Position.POWER_FORWARD]                    672                    326
# 2            [Position.CENTER]                    770                    187
# 3    [Position.SHOOTING_GUARD]                    227                     28
# 4    [Position.SHOOTING_GUARD]                    176                     35
# ..                         ...                    ...                    ...
# 562   [Position.POWER_FORWARD]                    560                     64
# 563     [Position.POINT_GUARD]                   1183                    531
# 564          [Position.CENTER]                    455                    159
# 565          [Position.CENTER]                     66                     18
# 566          [Position.CENTER]                    324                    129
#
#      attempted_three_point_field_goals  blocks  defensive_rebounds  \
# 0                                    3      61                 329
# 1                                   13      79                 489
# 2                                  153      83                 287
# 3                                  117       7                  72
# 4                                   91       1                  61
# ..                                 ...     ...                 ...
# 562                                205      20                 205
# 563                                533       8                 214
# 564                                 72      24                 234
# 565                                  0       5                  47
# 566                                  2      57                 274
#
#      games_played  games_started  ...  3pt_pcg  ft_pcg  raptor_offense  \
# 0              55             55  ...     0.33    0.60        1.125738
# 1              61             61  ...     0.08    0.69       -0.165734
# 2              52             52  ...     0.39    0.83       -0.719501
# 3              41              0  ...     0.34    0.61       -2.609379
# 4              30              0  ...     0.36    0.86       -0.402876
# ..            ...            ...  ...      ...     ...             ...
# 562            60             16  ...     0.37    0.59       -2.956376
# 563            57             57  ...     0.36    0.86        7.500200
# 564            54             35  ...     0.24    0.67       -0.596286
# 565            20              0  ...      NaN    0.78             NaN
# 566            61             59  ...     0.00    0.75        0.535135
#
#      raptor_defense  raptor_total  war_total       Team  Pos.  \
# 0          1.078578      2.204317   3.659296    Thunder     C
# 1          2.099525      1.933791   4.898266       Heat     C
# 2         -0.101252     -0.820753   1.666244      Spurs    PF
# 3         -2.066637     -4.676016  -0.494786   Pelicans    PG
# 4         -1.847584     -2.250460   0.127522  Grizzlies    SG
# ..              ...           ...        ...        ...   ...
# 562        0.714684     -2.241691   0.379694      Bulls    PF
# 563       -3.191613      4.308588   7.325524      Hawks    PG
# 564       -1.628820     -2.225105   0.327500    Hornets     C
# 565             NaN           NaN        NaN        NaN   NaN
# 566        3.020559      3.555694   3.469482   Clippers     C
#
#                        Build   OVR
# 0    Glass-Cleaning Lockdown  85.0
# 1                Paint Beast  83.0
# 2             3-Level Scorer  85.0
# 3                  Playmaker  72.0
# 4             3PT Specialist  72.0
# ..                       ...   ...
# 562        Inside-Out Scorer  76.0
# 563         Offensive Threat  90.0
# 564            Glass Cleaner  79.0
# 565                      NaN   NaN
# 566            Glass Cleaner  78.0
#
# [567 rows x 28 columns]

# %%
final_df = final_df.rename(columns={'raptor_offense':'offensive_rating', 'raptor_defense': 'defensive_rating',
                                   'raptor_total':'total_rating', 'war_total':'wins_above_replacement', 
                                    'Build':'nba_2k_strength', 'OVR':'nba_2k_rating'})
final_df.head()
# Out:
#                      Player                        team  \
# 0              Steven Adams  Team.OKLAHOMA_CITY_THUNDER
# 1               Bam Adebayo             Team.MIAMI_HEAT
# 2         LaMarcus Aldridge      Team.SAN_ANTONIO_SPURS
# 3  Nickeil Alexander-Walker   Team.NEW_ORLEANS_PELICANS
# 4             Grayson Allen      Team.MEMPHIS_GRIZZLIES
#
#                    positions  attempted_field_goals  attempted_free_throws  \
# 0          [Position.CENTER]                    428                    170
# 1   [Position.POWER_FORWARD]                    672                    326
# 2          [Position.CENTER]                    770                    187
# 3  [Position.SHOOTING_GUARD]                    227                     28
# 4  [Position.SHOOTING_GUARD]                    176                     35
#
#    attempted_three_point_field_goals  blocks  defensive_rebounds  \
# 0                                  3      61                 329
# 1                                 13      79                 489
# 2                                153      83                 287
# 3                                117       7                  72
# 4                                 91       1                  61
#
#    games_played  games_started  ...  3pt_pcg  ft_pcg  offensive_rating  \
# 0            55             55  ...     0.33    0.60          1.125738
# 1            61             61  ...     0.08    0.69         -0.165734
# 2            52             52  ...     0.39    0.83         -0.719501
# 3            41              0  ...     0.34    0.61         -2.609379
# 4            30              0  ...     0.36    0.86         -0.402876
#
#    defensive_rating  total_rating  wins_above_replacement       Team  Pos.  \
# 0          1.078578      2.204317                3.659296    Thunder     C
# 1          2.099525      1.933791                4.898266       Heat     C
# 2         -0.101252     -0.820753                1.666244      Spurs    PF
# 3         -2.066637     -4.676016               -0.494786   Pelicans    PG
# 4         -1.847584     -2.250460                0.127522  Grizzlies    SG
#
#            nba_2k_strength  nba_2k_rating
# 0  Glass-Cleaning Lockdown           85.0
# 1              Paint Beast           83.0
# 2           3-Level Scorer           85.0
# 3                Playmaker           72.0
# 4           3PT Specialist           72.0
#
# [5 rows x 28 columns]

# %%
final_df = final_df[['Player', 'Team', 'Pos.', 'fg_pcg',
       '3pt_pcg', 'ft_pcg', 'offensive_rating', 'defensive_rating',
       'total_rating', 'wins_above_replacement','nba_2k_strength', 'nba_2k_rating']]

final_df = final_df.dropna()
final_df
# Out:
#                        Player       Team Pos.  fg_pcg  3pt_pcg  ft_pcg  \
# 0                Steven Adams    Thunder    C    0.59     0.33    0.60
# 1                 Bam Adebayo       Heat    C    0.57     0.08    0.69
# 2           LaMarcus Aldridge      Spurs   PF    0.49     0.39    0.83
# 3    Nickeil Alexander-Walker   Pelicans   PG    0.34     0.34    0.61
# 4               Grayson Allen  Grizzlies   SG    0.45     0.36    0.86
# ..                        ...        ...  ...     ...      ...     ...
# 560              Delon Wright  Mavericks   PG    0.46     0.36    0.79
# 562            Thaddeus Young      Bulls   PF    0.45     0.37    0.59
# 563                Trae Young      Hawks   PG    0.44     0.36    0.86
# 564               Cody Zeller    Hornets    C    0.52     0.24    0.67
# 566               Ivica Zubac   Clippers    C    0.60     0.00    0.75
#
#      offensive_rating  defensive_rating  total_rating  wins_above_replacement  \
# 0            1.125738          1.078578      2.204317                3.659296
# 1           -0.165734          2.099525      1.933791                4.898266
# 2           -0.719501         -0.101252     -0.820753                1.666244
# 3           -2.609379         -2.066637     -4.676016               -0.494786
# 4           -0.402876         -1.847584     -2.250460                0.127522
# ..                ...               ...           ...                     ...
# 560          0.583401          0.070467      0.653867                2.170252
# 562         -2.956376          0.714684     -2.241691                0.379694
# 563          7.500200         -3.191613      4.308588                7.325524
# 564         -0.596286         -1.628820     -2.225105                0.327500
# 566          0.535135          3.020559      3.555694                3.469482
#
#              nba_2k_strength  nba_2k_rating
# 0    Glass-Cleaning Lockdown           85.0
# 1                Paint Beast           83.0
# 2             3-Level Scorer           85.0
# 3                  Playmaker           72.0
# 4             3PT Specialist           72.0
# ..                       ...            ...
# 560     Inside-Out Playmaker           79.0
# 562        Inside-Out Scorer           76.0
# 563         Offensive Threat           90.0
# 564            Glass Cleaner           79.0
# 566            Glass Cleaner           78.0
#
# [401 rows x 12 columns]

# %%
final_df["fg_pcg"] = final_df["fg_pcg"].map("{:.0%}".format)
final_df["ft_pcg"] = final_df["ft_pcg"].map("{:.0%}".format)
final_df["3pt_pcg"] = final_df["3pt_pcg"].map("{:.0%}".format)
final_df
# Out:
#                        Player       Team Pos. fg_pcg 3pt_pcg ft_pcg  \
# 0                Steven Adams    Thunder    C    59%     33%    60%
# 1                 Bam Adebayo       Heat    C    57%      8%    69%
# 2           LaMarcus Aldridge      Spurs   PF    49%     39%    83%
# 3    Nickeil Alexander-Walker   Pelicans   PG    34%     34%    61%
# 4               Grayson Allen  Grizzlies   SG    45%     36%    86%
# ..                        ...        ...  ...    ...     ...    ...
# 560              Delon Wright  Mavericks   PG    46%     36%    79%
# 562            Thaddeus Young      Bulls   PF    45%     37%    59%
# 563                Trae Young      Hawks   PG    44%     36%    86%
# 564               Cody Zeller    Hornets    C    52%     24%    67%
# 566               Ivica Zubac   Clippers    C    60%      0%    75%
#
#      offensive_rating  defensive_rating  total_rating  wins_above_replacement  \
# 0            1.125738          1.078578      2.204317                3.659296
# 1           -0.165734          2.099525      1.933791                4.898266
# 2           -0.719501         -0.101252     -0.820753                1.666244
# 3           -2.609379         -2.066637     -4.676016               -0.494786
# 4           -0.402876         -1.847584     -2.250460                0.127522
# ..                ...               ...           ...                     ...
# 560          0.583401          0.070467      0.653867                2.170252
# 562         -2.956376          0.714684     -2.241691                0.379694
# 563          7.500200         -3.191613      4.308588                7.325524
# 564         -0.596286         -1.628820     -2.225105                0.327500
# 566          0.535135          3.020559      3.555694                3.469482
#
#              nba_2k_strength  nba_2k_rating
# 0    Glass-Cleaning Lockdown           85.0
# 1                Paint Beast           83.0
# 2             3-Level Scorer           85.0
# 3                  Playmaker           72.0
# 4             3PT Specialist           72.0
# ..                       ...            ...
# 560     Inside-Out Playmaker           79.0
# 562        Inside-Out Scorer           76.0
# 563         Offensive Threat           90.0
# 564            Glass Cleaner           79.0
# 566            Glass Cleaner           78.0
#
# [401 rows x 12 columns]

# %%
final_df['offensive_rating'] = round(final_df['offensive_rating'],2)
final_df['defensive_rating'] = round(final_df['defensive_rating'],2)
final_df['total_rating'] = round(final_df['total_rating'],2)
final_df['wins_above_replacement'] = round(final_df['wins_above_replacement'],2)
final_df
# Out:
#                        Player       Team Pos. fg_pcg 3pt_pcg ft_pcg  \
# 0                Steven Adams    Thunder    C    59%     33%    60%
# 1                 Bam Adebayo       Heat    C    57%      8%    69%
# 2           LaMarcus Aldridge      Spurs   PF    49%     39%    83%
# 3    Nickeil Alexander-Walker   Pelicans   PG    34%     34%    61%
# 4               Grayson Allen  Grizzlies   SG    45%     36%    86%
# ..                        ...        ...  ...    ...     ...    ...
# 560              Delon Wright  Mavericks   PG    46%     36%    79%
# 562            Thaddeus Young      Bulls   PF    45%     37%    59%
# 563                Trae Young      Hawks   PG    44%     36%    86%
# 564               Cody Zeller    Hornets    C    52%     24%    67%
# 566               Ivica Zubac   Clippers    C    60%      0%    75%
#
#      offensive_rating  defensive_rating  total_rating  wins_above_replacement  \
# 0                1.13              1.08          2.20                    3.66
# 1               -0.17              2.10          1.93                    4.90
# 2               -0.72             -0.10         -0.82                    1.67
# 3               -2.61             -2.07         -4.68                   -0.49
# 4               -0.40             -1.85         -2.25                    0.13
# ..                ...               ...           ...                     ...
# 560              0.58              0.07          0.65                    2.17
# 562             -2.96              0.71         -2.24                    0.38
# 563              7.50             -3.19          4.31                    7.33
# 564             -0.60             -1.63         -2.23                    0.33
# 566              0.54              3.02          3.56                    3.47
#
#              nba_2k_strength  nba_2k_rating
# 0    Glass-Cleaning Lockdown           85.0
# 1                Paint Beast           83.0
# 2             3-Level Scorer           85.0
# 3                  Playmaker           72.0
# 4             3PT Specialist           72.0
# ..                       ...            ...
# 560     Inside-Out Playmaker           79.0
# 562        Inside-Out Scorer           76.0
# 563         Offensive Threat           90.0
# 564            Glass Cleaner           79.0
# 566            Glass Cleaner           78.0
#
# [401 rows x 12 columns]
